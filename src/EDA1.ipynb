# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('cleaned_race_data(1).csv')

# %%
df.head()
# Out:
#    Pos  No            Driver                      Car  Laps Time/Retired  \
# 0    1   1  Sebastian Vettel  Red Bull Racing Renault  58.0  1:29:30.259
# 1    1   1  Sebastian Vettel  Red Bull Racing Renault  58.0  1:29:30.259
# 2    1   1  Sebastian Vettel  Red Bull Racing Renault  58.0  1:29:30.259
# 3    1   1  Sebastian Vettel  Red Bull Racing Renault  58.0  1:29:30.259
# 4    1   1  Sebastian Vettel  Red Bull Racing Renault  58.0  1:29:30.259
#
#    PTS_race  Year Grand Prix DriverCode  ...            Time_summary  \
# 0      25.0  2011  Australia        VET  ...  0 days 01:29:30.259000
# 1      25.0  2011  Australia        VET  ...  0 days 01:29:30.259000
# 2      25.0  2011  Australia        VET  ...  0 days 01:29:30.259000
# 3      25.0  2011  Australia        VET  ...  0 days 01:29:30.259000
# 4      25.0  2011  Australia        VET  ...  0 days 01:29:30.259000
#
#    WinnerCode  PTS_team                  Team Stops  No_pitstop  Lap  \
# ...

# %%
df.describe()
# Out:
#                Pos           No         Laps     PTS_race         Year  \
# count  9814.000000  9814.000000  9814.000000  9814.000000  9814.000000
# mean      2.661504    23.223049    59.582229    18.706338  2016.182698
# std       3.119932    25.567232     9.138445     8.064322     3.735735
# min       0.000000     1.000000    12.000000     0.000000  2011.000000
# 25%       1.000000     3.000000    53.000000    15.000000  2013.000000
# 50%       1.000000     6.000000    57.000000    25.000000  2016.000000
# 75%       3.000000    44.000000    67.000000    25.000000  2020.000000
# max      19.000000    77.000000    87.000000    50.000000  2022.000000
#
#        PTS_details  Race Position  Pos_standings          PTS      No_grid  \
# count  9814.000000    9814.000000    9814.000000  9814.000000  9814.000000
# mean     18.853067       3.234970       2.729264   299.174445    23.223049
# std       8.146136       4.385785       2.099134    91.695001    25.567232
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9814 entries, 0 to 9813
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pos            9814 non-null   int64
#  1   No             9814 non-null   int64
#  2   Driver         9814 non-null   object
#  3   Car            9814 non-null   object
#  4   Laps           9814 non-null   float64
#  5   Time/Retired   9814 non-null   object
#  6   PTS_race       9814 non-null   float64
#  7   Year           9814 non-null   int64
#  8   Grand Prix     9814 non-null   object
#  9   DriverCode     9814 non-null   object
#  10  Date           9814 non-null   object
#  11  PTS_details    9814 non-null   float64
#  12  Race Position  9814 non-null   int64
#  13  Pos_standings  9814 non-null   int64
#  14  Nationality    9814 non-null   object
#  15  PTS            9814 non-null   float64
#  16  No_grid        9814 non-null   int64
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(y='Stops', data=df)
plt.title('Distribution of Pit Stops in F1 Races')
plt.ylabel('Number of Pit Stops')
plt.show()

# %%
columns_to_correlate = ['Race Position', 'Pos_grid', 'Laps', 'PTS_race', 'Stops',]
corr_matrix = df[columns_to_correlate].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Matrix: Variables Affecting Race Position')
plt.show()
